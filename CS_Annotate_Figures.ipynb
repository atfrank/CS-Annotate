# %% [markdown]
# <a href="https://colab.research.google.com/github/atfrank/CS-Annotate/blob/Kexin/CS_Annotate_Figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# %%
from google.colab import drive
drive.mount('/content/drive')
DIR_PATH = 'drive/My Drive/CS-Annotate/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Dataset exploration

# %%
trainy = pd.read_csv(DIR_PATH+"train_targets_dist.csv",header=0,delim_whitespace=True)
testy = pd.read_csv(DIR_PATH+"test_targets_dist.csv",header=0,delim_whitespace=True)

# %%
features=['astack', 'nastack', 'pair', "C1'-exo", "C2'-endo",
       "C2'-exo", "C3'-endo", "C3'-exo", "C4'-exo",
       'sasa', 'syn/anti']

fig = go.Figure(data=[
    go.Bar(name='Class 0', x=features, y=trainy.loc[0].tolist(),marker_color='#EB89B5'),
    go.Bar(name='Class 1', x=features, y=trainy.loc[1].tolist(),marker_color='#330C73')
])
# Change the bar mode
fig.update_layout(
    barmode='group',
    template='plotly_white',
    font=dict(family='Helvetica',size=32),
    xaxis_title_text='Structural Features',
    yaxis_title_text='Count', 
    bargap=0.2,
    legend=dict(
        x=0.9,
        y=1.2,
        traceorder="normal",
        bgcolor="LightGrey",
        bordercolor="Black",
        borderwidth=2
    ),
    width=2000,
    height=800
    #bargroupgap=0.1 
)
fig.update_yaxes(showgrid=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1977fc9-f135-4bfa-bd6f-fb920d87c3a8" class="plotly-graph-div" style="height:800px; width:2000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1977fc9-f135-4bfa-bd6f-fb920d87c3a8")) {
#                     Plotly.newPlot(
#                         'f1977fc9-f135-4bfa-bd6f-fb920d87c3a8',
#                         [{"marker": {"color": "#EB89B5"}, "name": "Class 0", "type": "bar", "x": ["astack", "nastack", "pair", "C1'-exo", "C2'-endo", "C2'-exo", "C3'-endo", "C3'-exo", "C4'-exo", "sasa", "syn/anti"], "y": [694, 2523, 744, 2764, 2646, 2542, 935, 2754, 2530, 2288, 2754]}, {"marker": {"color": "#330C73"}, "name": "Class 1", "type": "bar", "x": ["astack", "nastack", "pair", "C1'-exo", "C2'-endo", "C2'-exo", "C3'-endo", "C3'-exo", "C4'-exo", "sasa", "syn/anti"], "y": [2123, 294, 2073, 53, 171, 275, 1882, 63, 287, 529, 63]}],
#                         {"bargap": 0.2, "barmode": "group", "font": {"family": "Helvetica", "size": 32}, "height": 800, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 0.9, "y": 1.2}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker":  ...

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Compare independent MLP classifiers and chained classifiers

# %%
from sklearn.metrics import accuracy_score,f1_score,balanced_accuracy_score,recall_score,precision_score,classification_report,confusion_matrix
def calculate_score_chain_classifier(target,cv):
  # load in predictions
  #targets = ['astack', 'nastack', 'pair', "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", 'sasa', 'syn/anti']
  
  y_test = pd.read_csv(DIR_PATH+"chain/y_test_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_1 = pd.read_csv(DIR_PATH+"chain/pred_chain_0_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_2 = pd.read_csv(DIR_PATH+"chain/pred_chain_1_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_3 = pd.read_csv(DIR_PATH+"chain/pred_chain_2_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_4 = pd.read_csv(DIR_PATH+"chain/pred_chain_3_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_5 = pd.read_csv(DIR_PATH+"chain/pred_chain_4_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_6 = pd.read_csv(DIR_PATH+"chain/pred_chain_5_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_7 = pd.read_csv(DIR_PATH+"chain/pred_chain_6_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_8 = pd.read_csv(DIR_PATH+"chain/pred_chain_7_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_9 = pd.read_csv(DIR_PATH+"chain/pred_chain_8_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  chain_10 = pd.read_csv(DIR_PATH+"chain/pred_chain_9_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  ensemble = pd.read_csv(DIR_PATH+"chain/pred_ensemble_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  ovr = pd.read_csv(DIR_PATH+"chain/pred_ovr_cv_"+str(cv)+".csv",delim_whitespace=True,header=None)#,names=targets)
  # calculate balanced accuracy
  score_ovr = balanced_accuracy_score(y_test[target], ovr[target]>=0.5)
  score_chain_1 = balanced_accuracy_score(y_test[target], chain_1[target]>=0.5)
  score_chain_2 = balanced_accuracy_score(y_test[target], chain_2[target]>=0.5)
  score_chain_3 = balanced_accuracy_score(y_test[target], chain_3[target]>=0.5)
  score_chain_4 = balanced_accuracy_score(y_test[target], chain_4[target]>=0.5)
  score_chain_5 = balanced_accuracy_score(y_test[target], chain_5[target]>=0.5)
  score_chain_6 = balanced_accuracy_score(y_test[target], chain_6[target]>=0.5)
  score_chain_7 = balanced_accuracy_score(y_test[target], chain_7[target]>=0.5)
  score_chain_8 = balanced_accuracy_score(y_test[target], chain_8[target]>=0.5)
  score_chain_9 = balanced_accuracy_score(y_test[target], chain_9[target]>=0.5)
  score_chain_10 = balanced_accuracy_score(y_test[target], chain_10[target]>=0.5)
  ensemble_score = balanced_accuracy_score(y_test[target], ensemble[target]>=0.5)
  return [score_ovr,score_chain_1,score_chain_2,score_chain_3,score_chain_4,score_chain_5,score_chain_6,score_chain_7,score_chain_8,score_chain_9,score_chain_10,ensemble_score]

def draw_ensemble(target, scores): 
  models=["Validation Set 1", "Validation Set 2","Validation Set 3","Validation Set 4","Validation Set 5"]
  colors = ['indianred','lightsalmon','lightsalmon','lightsalmon','lightsalmon','lightsalmon','lightblue']
  fig = go.Figure()
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Base Model"]],
      name='Base Model',
      marker_color='indianred')
  )
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 1"]],
      name='Chain 1',
      marker_color='lightsalmon')
  )
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 2"]],
      name='Chain 2',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 3"]],
      name='Chain 3',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 4"]],
      name='Chain 4',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 5"]],
      name='Chain 5',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 6"]],
      name='Chain 6',
      marker_color='lightsalmon')
  )
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 7"]],
      name='Chain 7',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 8"]],
      name='Chain 8',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 9"]],
      name='Chain 9',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Chain 10"]],
      name='Chain 10',
      marker_color='lightsalmon'
  ))
  fig.add_trace(go.Bar(
      x=models,
      y=[round(num,3) for num in scores["Ensemble"]],
      name='Ensemble',
      marker_color='lightblue'
  ))

  fig.update_yaxes(range=[scores.min().min()*0.9, scores.max().max()*1.1])
  fig.update_layout(template="plotly_white",font=dict(family="Helvetica",size=24),
                    legend=dict(
                        x=1,
                        y=1,
                        traceorder="normal",
                        bgcolor="LightGrey",
                        bordercolor="Black",
                        borderwidth=2
                    ),
                    title={
                        'text': target,
                        'y':0.8,
                        'x':0.5,
                        'xanchor': 'center',
                        'yanchor': 'top'},
                    #width=2000,
                    #height=800
                    )
  fig.show()

def get_cv_scores(i, verbose=True):
  scores_1 = calculate_score_chain_classifier(i, 1)
  scores_2 = calculate_score_chain_classifier(i, 2)
  scores_3 = calculate_score_chain_classifier(i, 3)
  scores_4 = calculate_score_chain_classifier(i, 4)
  scores_5 = calculate_score_chain_classifier(i, 5)
  targets = ['Adjacent Stacking', 'Non-adjacent Stacking', 'Base Pairing', "C1'-exo", "C2'-endo",
        "C2'-exo", "C3'-endo", "C3'-exo", "C4'-exo",
        'SASA', 'Syn or Anti']
  scores = pd.DataFrame([scores_1,scores_2,scores_3,scores_4,scores_5])
  scores.columns = ["Base Model","Chain 1","Chain 2","Chain 3","Chain 4","Chain 5","Chain 6","Chain 7","Chain 8","Chain 9","Chain 10","Ensemble"]
  scores.index = ["Validation 1","Validation 2","Validation 3","Validation 4","Validation 5"]
  
  # this line for plotting validation score for each chain + ensemble classifier
  if verbose:
    draw_ensemble(target = targets[i], scores = scores) 
  # this line for overlaying chainclassifier and deepchem model
  return(scores)

# %%
# draw performance of classifier chain
for i in range(11):
  get_cv_scores(i, verbose=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e2005590-ae48-4198-bf9e-ed6bf688ece9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2005590-ae48-4198-bf9e-ed6bf688ece9")) {
#                     Plotly.newPlot(
#                         'e2005590-ae48-4198-bf9e-ed6bf688ece9',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.654, 0.702, 0.701, 0.69, 0.659]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.656, 0.698, 0.683, 0.688, 0.67]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.657, 0.713, 0.692, 0.672, 0.642]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.66, 0.683, 0.663, 0.68, 0.649]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.638, 0.704, 0.693, 0.654, 0.652]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.653, 0.691, 0.698, 0.684, 0.672]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.658, 0.709, 0.698, 0.693, 0.638]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.64, 0.707, 0.686, 0.687, 0.649]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.674, 0.717, 0.699, 0.661, 0.662]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.647, 0.661, 0.683, 0.681, 0.649]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.64, 0.695, 0.705, 0.689, 0.66]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.655, 0.71, 0.696, 0.678, 0.675]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f8d81bd-ae76-4c48-a9f3-70c6b49468cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f8d81bd-ae76-4c48-a9f3-70c6b49468cf")) {
#                     Plotly.newPlot(
#                         '8f8d81bd-ae76-4c48-a9f3-70c6b49468cf',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.682, 0.718, 0.743, 0.707, 0.683]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.694, 0.707, 0.736, 0.72, 0.715]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.7, 0.72, 0.742, 0.73, 0.694]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.714, 0.701, 0.718, 0.704, 0.709]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.723, 0.706, 0.709, 0.728, 0.698]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.713, 0.723, 0.73, 0.746, 0.697]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.719, 0.695, 0.758, 0.713, 0.688]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.689, 0.684, 0.732, 0.754, 0.677]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.736, 0.719, 0.717, 0.713, 0.716]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.715, 0.73, 0.726, 0.733, 0.728]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.712, 0.714, 0.74, 0.719, 0.684]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.71, 0.725, 0.735, 0.727, 0.673]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d116038e-0d72-4989-ab64-4c04a3886e50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d116038e-0d72-4989-ab64-4c04a3886e50")) {
#                     Plotly.newPlot(
#                         'd116038e-0d72-4989-ab64-4c04a3886e50',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.756, 0.764, 0.776, 0.751, 0.753]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.736, 0.767, 0.77, 0.745, 0.722]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.749, 0.781, 0.757, 0.745, 0.735]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.727, 0.771, 0.747, 0.708, 0.716]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.729, 0.788, 0.769, 0.749, 0.741]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.751, 0.777, 0.751, 0.721, 0.741]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.738, 0.772, 0.772, 0.738, 0.731]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.739, 0.779, 0.786, 0.734, 0.755]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.752, 0.766, 0.767, 0.717, 0.737]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.74, 0.793, 0.741, 0.727, 0.749]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.752, 0.786, 0.739, 0.742, 0.7]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.748, 0.79, 0.757, 0.733, 0.751]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e7759067-1567-4122-92f5-2c9cf5890447" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7759067-1567-4122-92f5-2c9cf5890447")) {
#                     Plotly.newPlot(
#                         'e7759067-1567-4122-92f5-2c9cf5890447',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.5, 0.571, 0.547, 0.558, 0.548]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.499, 0.571, 0.496, 0.554, 0.499]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.5, 0.536, 0.548, 0.558, 0.498]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.498, 0.536, 0.546, 0.557, 0.499]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.498, 0.571, 0.497, 0.556, 0.547]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.499, 0.535, 0.549, 0.558, 0.5]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.498, 0.606, 0.543, 0.553, 0.499]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.497, 0.605, 0.593, 0.553, 0.499]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.498, 0.571, 0.499, 0.558, 0.499]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.497, 0.571, 0.497, 0.557, 0.495]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.497, 0.571, 0.547, 0.557, 0.5]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.499, 0.571, 0.548, 0.558, 0.5]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="091e9400-ddee-4f09-8d70-334b0c9fe95a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("091e9400-ddee-4f09-8d70-334b0c9fe95a")) {
#                     Plotly.newPlot(
#                         '091e9400-ddee-4f09-8d70-334b0c9fe95a',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.584, 0.587, 0.636, 0.604, 0.591]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.568, 0.627, 0.632, 0.62, 0.641]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.57, 0.653, 0.651, 0.62, 0.625]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.598, 0.601, 0.649, 0.616, 0.671]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.602, 0.6, 0.619, 0.633, 0.675]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.628, 0.629, 0.687, 0.616, 0.694]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.551, 0.642, 0.678, 0.641, 0.626]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.641, 0.652, 0.682, 0.645, 0.666]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.657, 0.645, 0.679, 0.626, 0.686]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.609, 0.649, 0.73, 0.635, 0.669]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.568, 0.645, 0.661, 0.616, 0.607]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.599, 0.626, 0.648, 0.618, 0.675]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1d8b1925-b055-45c6-b8cb-46203c4f5e37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d8b1925-b055-45c6-b8cb-46203c4f5e37")) {
#                     Plotly.newPlot(
#                         '1d8b1925-b055-45c6-b8cb-46203c4f5e37',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.519, 0.543, 0.548, 0.527, 0.528]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.55, 0.591, 0.517, 0.517, 0.539]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.533, 0.559, 0.552, 0.529, 0.539]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.523, 0.563, 0.523, 0.517, 0.537]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.54, 0.563, 0.545, 0.535, 0.551]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.536, 0.592, 0.552, 0.512, 0.522]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.598, 0.536, 0.51, 0.517, 0.523]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.575, 0.593, 0.526, 0.504, 0.566]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.545, 0.579, 0.543, 0.528, 0.533]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.548, 0.56, 0.552, 0.541, 0.542]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.513, 0.579, 0.533, 0.516, 0.522]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.54, 0.581, 0.529, 0.529, 0.533]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9133ec98-339a-461a-9e53-05ff020c39f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9133ec98-339a-461a-9e53-05ff020c39f9")) {
#                     Plotly.newPlot(
#                         '9133ec98-339a-461a-9e53-05ff020c39f9',
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="469be286-783f-4c4a-ad9d-28868cbea819" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("469be286-783f-4c4a-ad9d-28868cbea819")) {
#                     Plotly.newPlot(
#                         '469be286-783f-4c4a-ad9d-28868cbea819',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.69, 0.744, 0.716, 0.691, 0.703]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.699, 0.748, 0.712, 0.71, 0.689]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.689, 0.77, 0.737, 0.706, 0.704]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.676, 0.724, 0.703, 0.703, 0.712]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.69, 0.779, 0.738, 0.708, 0.702]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.686, 0.728, 0.732, 0.702, 0.703]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.71, 0.75, 0.724, 0.698, 0.725]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.689, 0.738, 0.742, 0.705, 0.737]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.709, 0.754, 0.73, 0.703, 0.721]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.677, 0.736, 0.719, 0.693, 0.684]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.683, 0.73, 0.709, 0.715, 0.701]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.696, 0.751, 0.726, 0.707, 0.719]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c63bfa15-ea63-45b5-9bd9-60e6c189f19b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c63bfa15-ea63-45b5-9bd9-60e6c189f19b")) {
#                     Plotly.newPlot(
#                         'c63bfa15-ea63-45b5-9bd9-60e6c189f19b',
#                         [{"marker": {"color": "indianred"}, "name": "Base Model", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.65, 0.623, 0.652, 0.667, 0.745]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 1", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.648, 0.718, 0.653, 0.667, 0.748]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 2", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.648, 0.687, 0.614, 0.667, 0.787]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 3", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.697, 0.655, 0.653, 0.583, 0.789]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 4", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.649, 0.623, 0.691, 0.667, 0.787]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 5", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.647, 0.654, 0.653, 0.582, 0.789]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 6", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.649, 0.655, 0.653, 0.667, 0.745]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 7", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.649, 0.655, 0.69, 0.582, 0.79]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 8", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.648, 0.654, 0.651, 0.624, 0.789]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 9", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.65, 0.655, 0.65, 0.667, 0.745]}, {"marker": {"color": "lightsalmon"}, "name": "Chain 10", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.649, 0.687, 0.653, 0.624, 0.789]}, {"marker": {"color": "lightblue"}, "name": "Ensemble", "type": "bar", "x": ["Validation Set 1", "Validation Set 2", "Validation Set 3", "Validation Set 4", "Validation Set 5"], "y": [0.649, 0.655, 0.652, 0.667, 0.789]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 1, "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...

# %%
# compare ensemble and base learner
targets = ['astack', 'nastack', 'pair', "C1' exo", "C2' endo",
       "C2' exo", "C3' endo", "C3' exo", "C4' exo",
       'sasa', 'syn/anti']
scores_avg = []
for i in range(11):
  scores = get_cv_scores(i, verbose=False) # set verbose to False, do not draw figures
  avg = scores.apply(np.mean, axis=0).tolist()
  scores_avg.append(avg)

scores_avg = pd.DataFrame(scores_avg)
scores_avg.columns = ["Base Model","Chain 1","Chain 2","Chain 3","Chain 4","Chain 5","Chain 6","Chain 7","Chain 8","Chain 9","Chain 10","Ensemble"]
scores_avg.index = targets

fig = go.Figure()
fig.add_trace(go.Bar(y=scores_avg["Base Model"],x=targets,name="Independent Classifiers",marker_color='rgb(128,177,211)'))#,text=text1,mode="lines+markers+text",textposition="top center"))
fig.add_trace(go.Bar(y=scores_avg["Ensemble"],x=targets,name="Chained Ensemble",marker_color='rgb(253,180,105)'))
fig.update_layout(
    template = 'plotly_white',
    font=dict(family="Helvetica",size=28),width=1400,height=600,
    legend=dict(
        x=0.8,
        y=1.3,
        traceorder="normal",
        bgcolor="LightGrey",
        bordercolor="Black",
        borderwidth=2
        )
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7f64f952-22ce-40e5-a2de-a6b13bdeebaa" class="plotly-graph-div" style="height:600px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7f64f952-22ce-40e5-a2de-a6b13bdeebaa")) {
#                     Plotly.newPlot(
#                         '7f64f952-22ce-40e5-a2de-a6b13bdeebaa',
#                         [{"marker": {"color": "rgb(128,177,211)"}, "name": "Independent Classifiers", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6810728136379256, 0.7066683791261184, 0.7600505705899752, 0.5449806542528062, 0.6002701177122618, 0.5328803945278567, 0.6333949696501893, 0.5556390027285666, 0.5509429277799746, 0.7084766174867749, 0.6674665232189442]}, {"marker": {"color": "rgb(253,180,105)"}, "name": "Chained Ensemble", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6826893495490084, 0.7138122497749437, 0.7557588558601553, 0.535342317905609, 0.633133194516972, 0.5422841436065691, 0.6313321644929802, 0.5631461779363572, 0.5621792480895653, 0.7196889423516873, 0.6824148092954735]}],
#                         {"font": {"family": "Helvetica", "size": 28}, "height": 600, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 0.8, "y": 1.3}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "t ...

# %%
scores_avg.round(3)[['Base Model','Ensemble']]
# Out:
#           Base Model  Ensemble
# astack         0.681     0.683
# nastack        0.707     0.714
# pair           0.760     0.756
# C1' exo        0.545     0.535
# C2' endo       0.600     0.633
# C2' exo        0.533     0.542
# C3' endo       0.633     0.631
# C3' exo        0.556     0.563
# C4' exo        0.551     0.562
# sasa           0.708     0.720
# syn/anti       0.667     0.682

# %% [markdown]
# ## Compare chained classifiers and deepchem models

# %%
# load deepchem score
dc_cv = pd.read_csv(DIR_PATH+"deepchem_cv_neighbor_3.csv",delim_whitespace=True)

# %%
fig = go.Figure()

fig.add_trace(go.Bar(y=dc_cv.loc["mean"],x=targets,name="Progressive Neural Network",marker_color='rgb(128,177,211)'))#,text=text1,mode="lines+markers+text",textposition="top center"))
#fig.add_trace(go.Bar(y=mlp_cv["mean"],x=targets,name="MLP"))
fig.add_trace(go.Bar(y=scores_avg["Ensemble"],x=targets,name="Chained Ensemble",marker_color='rgb(253,180,105)'))
fig.update_layout(template = 'plotly_white',font=dict(family="Helvetica",size=24),width=1400,height=600,legend=dict(
        x=0.75,
        y=1.3,
        traceorder="normal",
        bgcolor="LightGrey",
        bordercolor="Black",
        borderwidth=2
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ecae484-1d54-41e0-a8aa-ca622c2ba57e" class="plotly-graph-div" style="height:600px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ecae484-1d54-41e0-a8aa-ca622c2ba57e")) {
#                     Plotly.newPlot(
#                         '0ecae484-1d54-41e0-a8aa-ca622c2ba57e',
#                         [{"marker": {"color": "rgb(128,177,211)"}, "name": "Progressive Neural Network", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6877074007644298, 0.8005708439382548, 0.7930621187950655, 0.6737931218922129, 0.7833257964920939, 0.5843040995630757, 0.6543242270887881, 0.8189430388532186, 0.5428963164347331, 0.7229917298756371, 0.7784247854948266]}, {"marker": {"color": "rgb(253,180,105)"}, "name": "Chained Ensemble", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6826893495490084, 0.7138122497749437, 0.7557588558601553, 0.535342317905609, 0.633133194516972, 0.5422841436065691, 0.6313321644929802, 0.5631461779363572, 0.5621792480895653, 0.7196889423516873, 0.6824148092954735]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "height": 600, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 0.75, "y": 1.3}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, " ...

# %% [markdown]
# # Neighboring effect

# %%
df_0 = pd.read_csv(DIR_PATH+"deepchem_cv_neighbor_0.csv",delim_whitespace=True)
df_1 = pd.read_csv(DIR_PATH+"deepchem_cv_neighbor_1.csv",delim_whitespace=True)
df_2 = pd.read_csv(DIR_PATH+"deepchem_cv_neighbor_2.csv",delim_whitespace=True)
df_3 = pd.read_csv(DIR_PATH+"deepchem_cv_neighbor_3.csv",delim_whitespace=True)
# Out:
#         astack   nastack      pair  ...  pucker_C4p_exo      sasa  syn_anti
# cv1   0.659730  0.781398  0.811316  ...        0.555359  0.720020  0.713899
# cv2   0.718561  0.822543  0.797044  ...        0.510000  0.711976  0.884057
# cv3   0.666044  0.798054  0.768489  ...        0.514248  0.706829  0.691441
# cv4   0.692146  0.811459  0.788337  ...        0.531926  0.731338  0.764056
# cv5   0.702056  0.789400  0.800125  ...        0.602949  0.744796  0.838671
# mean  0.687707  0.800571  0.793062  ...        0.542896  0.722992  0.778425
#
# [6 rows x 11 columns]

# %%
fig = go.Figure()
targets = ['astack', 'nastack', 'pair', "C1' exo", "C2' endo",
       "C2' exo", "C3' endo", "C3' exo", "C4' exo",
       'sasa', 'syn/anti']
fig.add_trace(go.Bar(y=df_0.loc["mean"],x=targets,name="Neighbor=0",marker_color='rgb(179,179,179)'))#,text=text1,mode="lines+markers+text",textposition="top center"))
#fig.add_trace(go.Bar(y=mlp_cv["mean"],x=targets,name="MLP"))
fig.add_trace(go.Bar(y=df_1.loc["mean"],x=targets,name="Neighbor=1",marker_color='rgb(179,205,227)'))#,text=text1,mode="lines+markers+text",textposition="top center"))
fig.add_trace(go.Bar(y=df_2.loc["mean"],x=targets,name="Neighbor=2",marker_color='rgb(128,177,211)'))
fig.add_trace(go.Bar(y=df_3.loc["mean"],x=targets,name="Neighbor=3",marker_color='rgb(55,126,184)'))

fig.update_layout(template = 'plotly_white',font=dict(family="Helvetica",size=24),width=1400,height=600,legend=dict(
        x=0.85,
        y=1.5,
        traceorder="normal",
        bgcolor="LightGrey",
        bordercolor="Black",
        borderwidth=2
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3b24e6d-3279-4e0b-816f-496ebda6f40d" class="plotly-graph-div" style="height:600px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3b24e6d-3279-4e0b-816f-496ebda6f40d")) {
#                     Plotly.newPlot(
#                         'd3b24e6d-3279-4e0b-816f-496ebda6f40d',
#                         [{"marker": {"color": "rgb(179,179,179)"}, "name": "Neighbor=0", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6705701207318935, 0.7182451448953925, 0.7225947331147959, 0.7203091675092936, 0.7786042883522738, 0.5838647342311791, 0.6306504581093302, 0.8075012227128766, 0.510699373288791, 0.6995668134831948, 0.8344679689144356]}, {"marker": {"color": "rgb(179,205,227)"}, "name": "Neighbor=1", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6828571587924809, 0.7845310516483327, 0.7781135913181139, 0.6976713651235069, 0.7860121055521129, 0.5603717230273866, 0.6442584302673522, 0.8203813477452453, 0.5274680147792324, 0.7190040487495228, 0.8013081814277875]}, {"marker": {"color": "rgb(128,177,211)"}, "name": "Neighbor=2", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6855709031795708, 0.7971500600862322, 0.7775876785738909, 0.7152721939544502, 0.7808394595171017, 0.5703360378649959, 0.6616646978061334, 0.8304609538760861, 0.5627559893435539, 0.7133698776737051, 0.8172418480138111]}, {"marker": {"color": "rgb(55,126,184)"}, "name": "Neighbor=3", "type": "bar", "x": ["astack", "nastack", "pair", "C1' exo", "C2' endo", "C2' exo", "C3' endo", "C3' exo", "C4' exo", "sasa", "syn/anti"], "y": [0.6877074007644298, 0.8005708439382548, 0.7930621187950655, 0.6737931218922129, 0.7833257964920939, 0.5843040995630757, 0.6543242270887881, 0.8189430388532186, 0.5428963164347331, 0.7229917298756371, 0.7784247854948266]}],
#                         {"font": {"family": "Helvetica", "size": 24}, "height": 600, "legend": {"bgcolor": "LightGrey", "bordercolor": "Black", "borderwidth": 2, "traceorder": "normal", "x": 0.85, "y": 1.5}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, " ...

# %%
predictions = pd.read_csv(DIR_PATH+"deepchem_testset_predictions.txt",delim_whitespace=True,header=0)
df = predictions[predictions['id']=="2N1Q"]

# %%
from sklearn.metrics import balanced_accuracy_score,accuracy_score,recall_score,classification_report,confusion_matrix
print(confusion_matrix(df['pair'],df['ppair']>=0.5))
# Out:
# [[1 1]
#  [2 3]]

# %%
df
# Out:
#       id  resid    sasa  ...  ppucker_C4p_exo     psasa     psyn_anti
# 83  2N1Q    108  177.03  ...         0.525100  0.518355  4.542611e-03
# 84  2N1Q    109  184.71  ...         0.266730  0.314611  3.022553e-08
# 85  2N1Q    110  185.35  ...         0.332993  0.996217  1.840899e-27
# 86  2N1Q    117  155.14  ...         0.501293  0.400744  8.301501e-03
# 87  2N1Q    118  159.88  ...         0.506780  0.922940  1.336847e-23
# 88  2N1Q    124  196.39  ...         0.426881  0.752381  1.535362e-19
# 89  2N1Q    130  172.40  ...         0.438207  0.710425  2.020245e-18
#
# [7 rows x 25 columns]
